# %% [markdown]
# <a href="https://colab.research.google.com/github/Faizan011-LTIM/Pandas-Python/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas
# Pandas is a python library used for data analysis and manupulation.
# It provide tool for handling structured data such as tables with powerful features to clean,filter and analyze data efficiently.

# %%
import pandas as pd                  # Import PANDAS Library
df = pd.read_excel("Sales.xlsx")     # Read the excel file
print(df)                            # Display the data in tabular form
# Out:
#     OrderID  OrderDate   Region  Manager                 Man_Email_ID  \
# 0         1 2018-01-06     East   Martha  alam.mdimtiyaz085@gmail.com
# 1         2 2018-01-23  Central  Hermann        ishtiaz2023@gmail.com
# 2         3 2018-02-09  Central  Hermann        ishtiaz2023@gmail.com
# 3         4 2018-02-26  Central  Timothy           ncec1320@gmail.com
# 4         5 2018-03-15     West  Timothy           ncec1320@gmail.com
# 5         6 2018-04-01     East   Martha  alam.mdimtiyaz085@gmail.com
# 6         7 2018-04-18  Central   Martha  alam.mdimtiyaz085@gmail.com
# 7         8 2018-05-05  Central  Hermann        ishtiaz2023@gmail.com
# 8         9 2018-05-22     West  Douglas   hussainakbar7786@gmail.com
# 9        10 2018-06-08     East   Martha  alam.mdimtiyaz085@gmail.com
# 10       11 2018-06-25  Central  Hermann        ishtiaz2023@gmail.com
# 11       12 2018-07-12     East   Martha  alam.mdimtiyaz085@gmail.com
# ...

# %%
import pandas as pd                     # Import PANDAS Library
df = pd.read_excel("Sales.xlsx")        # Read the excel file
display(df)                             # Show the data in table with format
# Out:
#     OrderID  OrderDate   Region  Manager                 Man_Email_ID  \
# 0         1 2018-01-06     East   Martha  alam.mdimtiyaz085@gmail.com
# 1         2 2018-01-23  Central  Hermann        ishtiaz2023@gmail.com
# 2         3 2018-02-09  Central  Hermann        ishtiaz2023@gmail.com
# 3         4 2018-02-26  Central  Timothy           ncec1320@gmail.com
# 4         5 2018-03-15     West  Timothy           ncec1320@gmail.com
# 5         6 2018-04-01     East   Martha  alam.mdimtiyaz085@gmail.com
# 6         7 2018-04-18  Central   Martha  alam.mdimtiyaz085@gmail.com
# 7         8 2018-05-05  Central  Hermann        ishtiaz2023@gmail.com
# 8         9 2018-05-22     West  Douglas   hussainakbar7786@gmail.com
# 9        10 2018-06-08     East   Martha  alam.mdimtiyaz085@gmail.com
# 10       11 2018-06-25  Central  Hermann        ishtiaz2023@gmail.com
# 11       12 2018-07-12     East   Martha  alam.mdimtiyaz085@gmail.com
# ...

# %%
import pandas as pd                     # Import PANDAS Library
df = pd.read_excel("Sales.xlsx")        # Read the excel file
df                                      # Show the data in table with format
# Out:
#     OrderID  OrderDate   Region  Manager                 Man_Email_ID  \
# 0         1 2018-01-06     East   Martha  alam.mdimtiyaz085@gmail.com
# 1         2 2018-01-23  Central  Hermann        ishtiaz2023@gmail.com
# 2         3 2018-02-09  Central  Hermann        ishtiaz2023@gmail.com
# 3         4 2018-02-26  Central  Timothy           ncec1320@gmail.com
# 4         5 2018-03-15     West  Timothy           ncec1320@gmail.com
# 5         6 2018-04-01     East   Martha  alam.mdimtiyaz085@gmail.com
# 6         7 2018-04-18  Central   Martha  alam.mdimtiyaz085@gmail.com
# 7         8 2018-05-05  Central  Hermann        ishtiaz2023@gmail.com
# 8         9 2018-05-22     West  Douglas   hussainakbar7786@gmail.com
# 9        10 2018-06-08     East   Martha  alam.mdimtiyaz085@gmail.com
# 10       11 2018-06-25  Central  Hermann        ishtiaz2023@gmail.com
# 11       12 2018-07-12     East   Martha  alam.mdimtiyaz085@gmail.com
# ...

# %%
import pandas as pd                # Import Pandas Library
df = pd.read_excel("Sales.xlsx")   # Read the excel file
df.head()                          # head()-To show top 5 record
# Out:
#    OrderID  OrderDate   Region  Manager                 Man_Email_ID  \
# 0        1 2018-01-06     East   Martha  alam.mdimtiyaz085@gmail.com
# 1        2 2018-01-23  Central  Hermann        ishtiaz2023@gmail.com
# 2        3 2018-02-09  Central  Hermann        ishtiaz2023@gmail.com
# 3        4 2018-02-26  Central  Timothy           ncec1320@gmail.com
# 4        5 2018-03-15     West  Timothy           ncec1320@gmail.com
#
#     SalesMan          Item  Units  Unit_price  Sale_amt
# 0  Alexander    Television     95      1198.0  113810.0
# 1     Shelli  Home Theater     50       400.0   20000.0
# 2       Luis    Television     36      1198.0   43128.0
# 3      David    Cell Phone     27       225.0    6075.0
# 4    Stephen    Television     56      1198.0   67088.0

# %%
import pandas as pd
df = pd.read_excel("Sales.xlsx")
df.tail()                         # tail() - To show bottom 5 records
# Out:
#     OrderID  OrderDate   Region  Manager                 Man_Email_ID  \
# 37       38 2019-09-27     West  Timothy           ncec1320@gmail.com
# 38       39 2019-10-14     West  Douglas   hussainakbar7786@gmail.com
# 39       40 2019-10-31  Central   Martha  alam.mdimtiyaz085@gmail.com
# 40       41 2014-12-20    North     Mark      farhanazam100@gmail.com
# 41       42 2014-12-20    North     Mark      farhanazam100@gmail.com
#
#    SalesMan          Item  Units  Unit_price  Sale_amt
# 37  Stephen    Cell Phone     76       225.0   17100.0
# 38  Michael  Home Theater     57       500.0   28500.0
# 39   Steven    Television     14      1198.0   16772.0
# 40  Stephen      Earphone     10       245.0    2450.0
# 41  Stephen        Tablet     15      7600.0  114000.0

# %%
import pandas as pd                                          # Import Pandas Library
df = pd.read_excel("Sales.xlsx")                             # Read Excel File
sel_col = df[['OrderID', 'Region', 'Manager', 'Sale_amt']]   # To show desired Column
sel_col                                                      # Show all records
# Out:
#     OrderID   Region  Manager  Sale_amt
# 0         1     East   Martha  113810.0
# 1         2  Central  Hermann   20000.0
# 2         3  Central  Hermann   43128.0
# 3         4  Central  Timothy    6075.0
# 4         5     West  Timothy   67088.0
# 5         6     East   Martha   30000.0
# 6         7  Central   Martha   89850.0
# 7         8  Central  Hermann  107820.0
# 8         9     West  Douglas   38336.0
# 9        10     East   Martha   30000.0
# 10       11  Central  Hermann  107820.0
# 11       12     East   Martha   14500.0
# 12       13     East  Douglas   40500.0
# 13       14     East   Martha   41930.0
# 14       15  Central  Douglas     250.0
# 15       16     East   Martha     936.0
# 16       17  Central  Hermann   14000.0
# 17       18     East   Martha   14400.0
# 18       19     East  Douglas    3375.0
# 19       20  Central  Hermann    5616.0
# 20       21  Central  Douglas   80266.0
# 21       22     East  Douglas    4329.0
# ...

# %%
import pandas as pd                                          # Import Pandas Library
df = pd.read_excel("Sales.xlsx")                             # Read Excel File
sel_col = df[['OrderID', 'Region', 'Manager', 'Sale_amt']]   # To show desired Column
sel_col.head()                                               # Show the top 5 records
# Out:
#    OrderID   Region  Manager  Sale_amt
# 0        1     East   Martha  113810.0
# 1        2  Central  Hermann   20000.0
# 2        3  Central  Hermann   43128.0
# 3        4  Central  Timothy    6075.0
# 4        5     West  Timothy   67088.0

# %%
import pandas as pd
df = pd.read_excel("Sales.xlsx")
east_data = df[df["Region"] == "East"]        # To display the record with one condition
east_data
# Out:
#     OrderID  OrderDate Region  Manager                 Man_Email_ID  \
# 0         1 2018-01-06   East   Martha  alam.mdimtiyaz085@gmail.com
# 5         6 2018-04-01   East   Martha  alam.mdimtiyaz085@gmail.com
# 9        10 2018-06-08   East   Martha  alam.mdimtiyaz085@gmail.com
# 11       12 2018-07-12   East   Martha  alam.mdimtiyaz085@gmail.com
# 12       13 2018-07-29   East  Douglas   hussainakbar7786@gmail.com
# 13       14 2018-08-15   East   Martha  alam.mdimtiyaz085@gmail.com
# 15       16 2018-09-18   East   Martha  alam.mdimtiyaz085@gmail.com
# 17       18 2018-10-22   East   Martha  alam.mdimtiyaz085@gmail.com
# 18       19 2018-11-08   East  Douglas   hussainakbar7786@gmail.com
# 21       22 2018-12-29   East  Douglas   hussainakbar7786@gmail.com
# 24       25 2019-02-18   East   Martha  alam.mdimtiyaz085@gmail.com
# 28       29 2019-04-27   East   Martha  alam.mdimtiyaz085@gmail.com
# 32       33 2019-07-04   East   Martha  alam.mdimtiyaz085@gmail.com
#
# ...
